# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Banking.csv')

# %%
df.head()
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
# statistical information
df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
df['Estimated Income'].min()
# Out:
# 15919.48

# %%
df['Estimated Income'].max()
# Out:
# 522330.26

# %%
bins = [0,100000,300000,float('inf')]
labels = ['Low','Medium','High']

df['Income Band'] = pd.cut(df['Estimated Income'],bins=bins,labels=labels,right=False)

# %%
df[['Estimated Income','Income Band']].head()
# Out:
#    Estimated Income Income Band
# 0          75384.77         Low
# 1         289834.31      Medium
# 2         169935.23      Medium
# 3         356808.11        High
# 4         130711.68      Medium

# %%
df['Income Band'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Income Band'>

# %%
df.columns
# Out:
# Index(['Client ID', 'Name', 'Age', 'Location ID', 'Joined Bank',
#        'Banking Contact', 'Nationality', 'Occupation', 'Fee Structure',
#        'Loyalty Classification', 'Estimated Income', 'Superannuation Savings',
#        'Amount of Credit Cards', 'Credit Card Balance', 'Bank Loans',
#        'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
#        'Foreign Currency Account', 'Business Lending', 'Properties Owned',
#        'Risk Weighting', 'BRId', 'GenderId', 'IAId', 'Income Band'],
#       dtype='object')

# %%
# Examine the unique categories in categories column
categorical_cols = df[['Nationality','Fee Structure','Loyalty Classification',
                       'Amount of Credit Cards','Risk Weighting','BRId','GenderId','IAId','Properties Owned','Income Band']]

for col in categorical_cols.columns:
    print(f"The value counts for {col} is")
    display(df[col].value_counts())
# Out:
# The value counts for Nationality is
# Nationality
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# Name: count, dtype: int64
# The value counts for Fee Structure is
# Fee Structure
# High    1476
# Mid      962
# Low      562
# Name: count, dtype: int64
# The value counts for Loyalty Classification is
# Loyalty Classification
# Jade        1331
# Silver       767
# Gold         585
# Platinum     317
# Name: count, dtype: int64
# The value counts for Amount of Credit Cards is
# Amount of Credit Cards
# 1    1922
# 2     765
# 3     313
# Name: count, dtype: int64
# The value counts for Risk Weighting is
# Risk Weighting
# 2    1222
# 1     836
# 3     460
# 4     322
# 5     160
# Name: count, dtype: int64
# The value counts for BRId is
# BRId
# 3    1352
# 1     660
# 2     495
# 4     493
# Name: count, dtype: int64
# The value counts for GenderId is
# GenderId
# 2    1512
# 1    1488
# Name: count, dtype: int64
# ...

# %% [markdown]
# ## univariate analysis

# %%
for i,predictor in enumerate(df[['Nationality','Fee Structure','Loyalty Classification','Amount of Credit Cards','Risk Weighting','BRId','GenderId','IAId','Properties Owned','Income Band']]):
    plt.figure(i)
    sns.countplot(data=df,x=predictor)

# %% [markdown]
# ## Bivariate analysis

# %%
for i,predictor in enumerate(df[['Nationality','Fee Structure','Loyalty Classification','Amount of Credit Cards','Risk Weighting','BRId','GenderId','IAId','Properties Owned','Income Band']]):
    plt.figure(i)
    sns.countplot(data=df,x=predictor,hue='Nationality')

# %% [markdown]
# ## Numerical Analysis

# %%
numerical_cols = ['Estimated Income', 'Superannuation Savings', 'Credit Card Balance', 'Bank Loans', 
                  'Bank Deposits', 'Checking Accounts', 'Saving Accounts', 'Foreign Currency Account', 'Business Lending']

# univariate analysis
plt.figure(figsize=(20,20))
for i,col in enumerate(numerical_cols):
    plt.subplot(3,3,i+1)
    sns.histplot(df[col],kde=True)
    plt.title(col)
plt.show()

# %%
df['Estimated Income'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ## heatmap

# %%
correlation_matrix = df[numerical_cols].corr()

plt.figure(figsize=(10,5))

sns.heatmap(correlation_matrix,cmap='crest',fmt='.2f',annot=True)
plt.title("Heat map for numerical columns")
plt.show()

# %% [markdown]
# ## EDA insights
# 1. There is a strong correlation between "Bank deposits" with "Checking Accounts","Savings account" and "Foreign Currency account"
#    which means customers have high funds on one account will have funds in other accounts.
# 2. Most of the customers are from Europe, Asia and America
